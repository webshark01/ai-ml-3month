# %%
import numpy as np

# %%
import numpy as np

A = np.array([[2, 0],
              [1, 3]])

B = np.array([[4, 1],
              [2, 5]])

print(A @ B)
# Out:
# [[ 8  2]
#  [10 16]]

# %%
A = np.array([[1,2],[3,4],[5,6]])
print(A.T)
# Out:
# [[1 3 5]
#  [2 4 6]]
